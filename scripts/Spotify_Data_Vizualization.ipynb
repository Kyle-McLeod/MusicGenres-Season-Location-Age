# %%
# %matplotlib notebook

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
file = Path('Resources/Cleaned_Genres_2019_2020.csv')

# %%
music_df = pd.read_csv(file, encoding="UTF-8")
music_df.head()
# Out:
#    Position                                      Track Name         Artist  \
# 0         1                                   thank u;;next  Ariana Grande
# 1         2   Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 2         3  Taki Taki (with Selena Gomez;;Ozuna & Cardi B)       DJ Snake
# 3         4                                            Wow.    Post Malone
# 4         5                               MIA (feat. Drake)      Bad Bunny
#
#    Streams      Date      Genre
# 0  3978028  1/1/2019        Pop
# 1  3883836  1/1/2019        Rap
# 2  3351784  1/1/2019        Edm
# 3  3195966  1/1/2019        Rap
# 4  2777884  1/1/2019  Reggaeton

# %%
music_df["Genre"].unique()
# Out:
# array(['Pop', 'Rap', 'Edm', 'Reggaeton', 'Hip Hop', 'Rock', 'R&B',
#        'Other'], dtype=object)

# %%
music_df["Genre"].value_counts()
# Out:
# Pop          44389
# Rap          25689
# Hip Hop      20963
# Reggaeton    19998
# Edm          12336
# Rock         11353
# R&B           6136
# Other         4136
# Name: Genre, dtype: int64

# %%
music_df
# Out:
#         Position                                      Track Name  \
# 0              1                                   thank u;;next
# 1              2   Sunflower - Spider-Man: Into the Spider-Verse
# 2              3  Taki Taki (with Selena Gomez;;Ozuna & Cardi B)
# 3              4                                            Wow.
# 4              5                               MIA (feat. Drake)
# ...          ...                                             ...
# 144995       196                                        MAMACITA
# 144996       197                                         Falling
# 144997       198                  Uptown Funk (feat. Bruno Mars)
# 144998       199                                  Jocelyn Flores
# 144999       200                           Every Breath You Take
#
#                  Artist  Streams        Date      Genre
# 0         Ariana Grande  3978028    1/1/2019        Pop
# 1           Post Malone  3883836    1/1/2019        Rap
# ...

# %%
music_df.dtypes
# Out:
# Position       int64
# Track Name    object
# Artist        object
# Streams        int64
# Date          object
# Genre         object
# dtype: object

# %%
music_df["Genre"] = music_df["Genre"].astype("string")
music_df.dtypes
# Out:
# Position       int64
# Track Name    object
# Artist        object
# Streams        int64
# Date          object
# Genre         string
# dtype: object

# %%
pop_music_df = music_df.loc[music_df["Genre"] == "Pop"]
pop_music_df
# Out:
#         Position                      Track Name         Artist  Streams  \
# 0              1                   thank u;;next  Ariana Grande  3978028
# 6              7                      Without Me         Halsey  2618489
# 7              8                Sweet but Psycho        Ava Max  2432084
# 8              9                   Calma - Remix     Pedro Capó  2385494
# 22            23                         Shallow      Lady Gaga  1569388
# ...          ...                             ...            ...      ...
# 144989       190                       24K Magic     Bruno Mars   892291
# 144993       194                   Dancing Queen           ABBA   876108
# 144994       195    Some Say - Felix Jaehn Remix            Nea   874224
# 144996       197                         Falling   Harry Styles   871511
# 144997       198  Uptown Funk (feat. Bruno Mars)    Mark Ronson   869870
#
#               Date Genre
# 0         1/1/2019   Pop
# 6         1/1/2019   Pop
# ...

# %%
print(pop_music_df["Streams"].max())
print(pop_music_df["Streams"].min())
# Out:
# 12229331
# 525117

# %%
plt.ylim(525117, 12229331)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (525117.0, 12229331.0)

# %%
dates = pop_music_df["Date"]
streams = pop_music_df["Streams"]

# %%
stream_count = plt.plot(dates, streams, color="red", label="Stream Count")
plt.show()
